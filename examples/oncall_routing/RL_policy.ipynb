# %%
# Copyright (c) Microsoft Corporation.
# Licensed under the MIT license.

from typing import List, Optional, Tuple, Dict

from maro.simulator import Env
from maro.simulator.scenarios.oncall_routing import Coordinate
from maro.simulator.scenarios.oncall_routing.common import Action, PostponeAction, OncallRoutingPayload, AllocateAction
from maro.simulator.scenarios.oncall_routing.order import OrderStatus
from maro.utils import set_seeds
import pandas as pd
from greedy2 import _get_actions
# from greedy_with_time_window import _get_actions
# from greedy import _get_actions

from examples.oncall_routing.utils import refresh_segment_index

set_seeds(2048)

oncall_id_list = []

def order_status2_str(order_status):
    if order_status == OrderStatus.NOT_READY:
        return "NotReady"
    elif order_status == OrderStatus.READY_IN_ADVANCE:
        return "ReadyInAdvance"
    elif order_status == OrderStatus.IN_PROCESS:
        return "InProcess"
    elif order_status == OrderStatus.IN_PROCESS_BUT_DELAYED:
        return "Delayed"
    elif order_status == OrderStatus.COMPLETED:
        return "Complete"
    elif order_status == OrderStatus.TERMINATED:
        return "Terminated"
    else:
        return "Dummy"

def collect_info(running_env: Env, event: OncallRoutingPayload):
    result_list = []
    tick = running_env.tick
    route_meta_info_dict = running_env.business_engine._get_route_meta_info_dict(tick)
    carriers_in_stop: List[bool] = (running_env.snapshot_list["carriers"][tick::"in_stop"] == 1).tolist()
    carrier_position_dict: Dict[str, Tuple[bool, int, int, Coordinate]] = {
        route_name: [
            carriers_in_stop[meta["carrier_idx"]],
            meta["estimated_duration_to_the_next_stop"],
            meta["estimated_next_departure_tick"],
            meta["current_staying_stop_coordinate"]
        ]
        for route_name, meta in route_meta_info_dict.items()
    }
    finished_orders = running_env.business_engine.get_finished_orders_dict()
    for route_name in finished_orders.keys():
        meta = route_meta_info_dict[route_name]
        for order, finished_tick in finished_orders[route_name]:
            result = [tick, route_name, 'COMPLETED', 
                      order.coord[0], 
                      order.coord[1], 
                      finished_tick,
                      order.open_time,
                      order.close_time,
                      order.is_delivery,
                      order_status2_str(order._status),
                      meta['carrier_idx'],
                      (-1 if carrier_position_dict[route_name][3] is None else carrier_position_dict[route_name][3][0]),
                      (-1 if carrier_position_dict[route_name][3] is None else carrier_position_dict[route_name][3][1]),
                      order.id
                     ]
            result_list.append(result)
    if event:
        oncall_orders = event.oncall_orders
        route_plan_dict = event.route_plan_dict
        for route_name, meta in route_meta_info_dict.items():
            planned_orders = route_plan_dict[route_name]
            for i, planned_order in enumerate(planned_orders):
                result = [tick, route_name, 'PLANNED', 
                        planned_order.coord[0], 
                        planned_order.coord[1], 
                        tick,
                        planned_order.open_time,
                        planned_order.close_time,
                        planned_order.is_delivery,
                        order_status2_str(planned_order.get_status(tick, env.business_engine._config.order_transition)),
                        meta['carrier_idx'],
                        (-1 if carrier_position_dict[route_name][3] is None else carrier_position_dict[route_name][3][0]),
                        (-1 if carrier_position_dict[route_name][3] is None else carrier_position_dict[route_name][3][1]),
                        planned_order.id
                        ]
                result_list.append(result)
        for oncall_order in oncall_orders:
            oncall_id_list.append(oncall_order.id)
            result = [tick, "Not Assigned", 'ONCALL', 
                    oncall_order.coord[0], 
                    oncall_order.coord[1], 
                    tick,
                    oncall_order.open_time,
                    oncall_order.close_time,
                    oncall_order.is_delivery,
                    order_status2_str(oncall_order.get_status(tick, env.business_engine._config.order_transition)),
                    -1,
                    -1,
                    -1,
                    oncall_order.id
                    ]
            result_list.append(result)
    df_orders = pd.DataFrame(data=result_list, 
                             columns=['tick', 'route_name', 'type',
                                      'order_lat', 'order_lng', 'finish_tick', 
                                      'open_time', 'close_time',
                                      'is_delivery', 'order_status',
                                      'carrier_id', 'carrier_lat', 'carrier_lng', 'order_id'])
    # df_orders.to_csv('hist_orders.csv', index=False)
    return df_orders


# Greedy: assign each on-call order to the closest stop on existing route.
if __name__ == "__main__":
    env = Env(
        scenario="oncall_routing", topology="example", start_tick=400, durations=1000,
    )
    print(env._business_engine._max_tick)
    print(env._business_engine._config.order_transition)
    env.reset(keep_seed=True)
    metrics, decision_event, is_done = env.step(None)
    df_list = []
    while not is_done:
        assert isinstance(decision_event, OncallRoutingPayload)
        df_orders = collect_info(env, decision_event)
        df_list.append(df_orders)
        print(f"Processing {len(decision_event.oncall_orders)} oncall orders at tick {env.tick}.")
        # metrics, decision_event, is_done = env.step(_get_actions(env, decision_event))
        # for oncall_order in decision_event.oncall_orders:
        metrics, decision_event, is_done = env.step(_get_actions(env, decision_event))
    df_orders = collect_info(env, None)
    df_list.append(df_orders)
    df = pd.concat(df_list)
    df.loc[:, 'type'] = df.apply(lambda row: ("ONCALL" if row['order_id'] in oncall_id_list else "PLANNED"), axis=1)
    df.to_csv("hist_routing_orders.csv", index=False)
    print(env.tick)  
    print(env.metrics)
# Out:
# Config path: /Users/songlei/Library/CloudStorage/OneDrive-Personal/MSRA/Research/codes/smartMARO/maro/simulator/scenarios/oncall_routing/topologies/example
# Loading oncall orders.
# oncall 338
# Loading plans.
# Loading routes data from /Users/songlei/Library/CloudStorage/OneDrive-Personal/MSRA/Research/codes/smartMARO/maro/simulator/scenarios/oncall_routing/topologies/example/routes.csv.
# Loading finished. Loaded data of 117 routes.
# 1420
# {'buffer_before_open_time': 30, 'buffer_after_open_time': 30, 'last_tick_for_order_processing': 1400, 'processing_time': 1, 'processing_proportion_to_quantity': False}
# oncall 338
# Processing 1 oncall orders at tick 286.
# Processing 1 oncall orders at tick 318.
# Processing 1 oncall orders at tick 321.
# Processing 1 oncall orders at tick 339.
# Processing 1 oncall orders at tick 353.
# Processing 1 oncall orders at tick 364.
# Processing 1 oncall orders at tick 371.
# Processing 2 oncall orders at tick 374.
# Processing 1 oncall orders at tick 376.
# Processing 2 oncall orders at tick 380.
# Processing 2 oncall orders at tick 382.
# Processing 1 oncall orders at tick 391.
# Processing 1 oncall orders at tick 395.
# Processing 1 oncall orders at tick 407.
# Processing 1 oncall orders at tick 410.
# Processing 2 oncall orders at tick 415.
# Processing 2 oncall orders at tick 424.
# Processing 2 oncall orders at tick 426.
# Processing 6 oncall orders at tick 429.
# Processing 1 oncall orders at tick 434.
# Processing 3 oncall orders at tick 436.
# Processing 2 oncall orders at tick 438.
# Processing 1 oncall orders at tick 440.
# Processing 1 oncall orders at tick 452.
# Processing 1 oncall orders at tick 455.
# Processing 2 oncall orders at tick 459.
# Processing 1 oncall orders at tick 462.
# Processing 1 oncall orders at tick 467.
# Processing 1 oncall orders at tick 469.
# Processing 1 oncall orders at tick 473.
# Processing 1 oncall orders at tick 476.
# Processing 1 oncall orders at tick 479.
# Processing 2 oncall orders at tick 483.
# Processing 1 oncall orders at tick 485.
# Processing 2 oncall orders at tick 488.
# Processing 2 oncall orders at tick 490.
# Processing 2 oncall orders at tick 492.
# Processing 3 oncall orders at tick 494.
# Processing 1 oncall orders at tick 498.
# Processing 2 oncall orders at tick 500.
# Processing 3 oncall orders at tick 505.
# Processing 1 oncall orders at tick 507.
# Processing 2 oncall orders at tick 513.
# Processing 5 oncall orders at tick 516.
# Processing 1 oncall orders at tick 524.
# Processing 1 oncall orders at tick 527.
# Processing 2 oncall orders at tick 529.
# Processing 3 oncall orders at tick 531.
# Processing 2 oncall orders at tick 534.
# Processing 2 oncall orders at tick 536.
# Processing 1 oncall orders at tick 538.
# Processing 1 oncall orders at tick 541.
# Processing 2 oncall orders at tick 543.
# Processing 1 oncall orders at tick 546.
# Processing 2 oncall orders at tick 550.
# Processing 2 oncall orders at tick 552.
# Processing 1 oncall orders at tick 555.
# Processing 3 oncall orders at tick 557.
# Processing 2 oncall orders at tick 560.
# Processing 2 oncall orders at tick 562.
# Processing 1 oncall orders at tick 565.
# Processing 1 oncall orders at tick 567.
# Processing 2 oncall orders at tick 570.
# Processing 1 oncall orders at tick 573.
# Processing 1 oncall orders at tick 585.
# Processing 2 oncall orders at tick 587.
# Processing 1 oncall orders at tick 589.
# Processing 2 oncall orders at tick 596.
# Processing 3 oncall orders at tick 598.
# Processing 1 oncall orders at tick 603.
# Processing 3 oncall orders at tick 605.
# Processing 2 oncall orders at tick 608.
# Processing 1 oncall orders at tick 611.
# Processing 1 oncall orders at tick 613.
# Processing 3 oncall orders at tick 615.
# Processing 3 oncall orders at tick 617.
# Processing 2 oncall orders at tick 619.
# Processing 2 oncall orders at tick 622.
# Processing 1 oncall orders at tick 624.
# Processing 2 oncall orders at tick 626.
# Processing 3 oncall orders at tick 629.
# Processing 3 oncall orders at tick 634.
# Processing 1 oncall orders at tick 636.
# Processing 1 oncall orders at tick 638.
# Processing 1 oncall orders at tick 642.
# Processing 1 oncall orders at tick 644.
# Processing 2 oncall orders at tick 646.
# Processing 2 oncall orders at tick 648.
# Processing 2 oncall orders at tick 650.
# Processing 3 oncall orders at tick 654.
# Processing 3 oncall orders at tick 656.
# Processing 2 oncall orders at tick 658.
# Processing 3 oncall orders at tick 661.
# Processing 1 oncall orders at tick 663.
# Processing 2 oncall orders at tick 665.
# Processing 2 oncall orders at tick 667.
# Processing 3 oncall orders at tick 669.
# Processing 3 oncall orders at tick 672.
# Processing 1 oncall orders at tick 674.
# Processing 2 oncall orders at tick 676.
# Processing 1 oncall orders at tick 679.
# Processing 2 oncall orders at tick 681.
# Processing 2 oncall orders at tick 684.
# Processing 4 oncall orders at tick 686.
# Processing 2 oncall orders at tick 690.
# Processing 4 oncall orders at tick 692.
# Processing 2 oncall orders at tick 694.
# Processing 1 oncall orders at tick 696.
# Processing 1 oncall orders at tick 699.
# Processing 1 oncall orders at tick 704.
# Processing 1 oncall orders at tick 706.
# Processing 3 oncall orders at tick 708.
# Processing 2 oncall orders at tick 712.
# Processing 1 oncall orders at tick 714.
# Processing 1 oncall orders at tick 716.
# Processing 1 oncall orders at tick 719.
# Processing 3 oncall orders at tick 722.
# Processing 2 oncall orders at tick 724.
# Processing 3 oncall orders at tick 730.
# Processing 2 oncall orders at tick 733.
# Processing 3 oncall orders at tick 735.
# Processing 3 oncall orders at tick 738.
# Processing 2 oncall orders at tick 740.
# Processing 2 oncall orders at tick 742.
# Processing 1 oncall orders at tick 746.
# Processing 2 oncall orders at tick 748.
# Processing 6 oncall orders at tick 750.
# Processing 2 oncall orders at tick 752.
# Processing 1 oncall orders at tick 754.
# Processing 1 oncall orders at tick 756.
# Processing 3 oncall orders at tick 759.
# Processing 1 oncall orders at tick 764.
# Processing 3 oncall orders at tick 767.
# Processing 1 oncall orders at tick 770.
# Processing 2 oncall orders at tick 772.
# Processing 2 oncall orders at tick 774.
# Processing 1 oncall orders at tick 776.
# Processing 1 oncall orders at tick 778.
# Processing 4 oncall orders at tick 780.
# Processing 2 oncall orders at tick 783.
# Processing 2 oncall orders at tick 788.
# Processing 2 oncall orders at tick 791.
# Processing 2 oncall orders at tick 793.
# Processing 5 oncall orders at tick 795.
# Processing 2 oncall orders at tick 798.
# Processing 1 oncall orders at tick 801.
# Processing 1 oncall orders at tick 805.
# Processing 3 oncall orders at tick 808.
# Processing 3 oncall orders at tick 810.
# Processing 4 oncall orders at tick 812.
# Processing 1 oncall orders at tick 815.
# Processing 1 oncall orders at tick 821.
# Processing 5 oncall orders at tick 823.
# Processing 2 oncall orders at tick 828.
# Processing 1 oncall orders at tick 831.
# Processing 2 oncall orders at tick 836.
# Processing 1 oncall orders at tick 838.
# Processing 1 oncall orders at tick 842.
# Processing 1 oncall orders at tick 846.
# Processing 1 oncall orders at tick 852.
# Processing 1 oncall orders at tick 855.
# Processing 2 oncall orders at tick 857.
# Processing 2 oncall orders at tick 860.
# Processing 1 oncall orders at tick 862.
# Processing 1 oncall orders at tick 864.
# Processing 1 oncall orders at tick 867.
# Processing 2 oncall orders at tick 872.
# Processing 1 oncall orders at tick 875.
# Processing 3 oncall orders at tick 877.
# Processing 2 oncall orders at tick 879.
# Processing 1 oncall orders at tick 881.
# Processing 2 oncall orders at tick 887.
# Processing 2 oncall orders at tick 892.
# Processing 1 oncall orders at tick 894.
# Processing 1 oncall orders at tick 899.
# Processing 2 oncall orders at tick 905.
# Processing 1 oncall orders at tick 916.
# Processing 2 oncall orders at tick 921.
# Processing 1 oncall orders at tick 924.
# Processing 1 oncall orders at tick 928.
# Processing 1 oncall orders at tick 932.
# Processing 1 oncall orders at tick 936.
# Processing 2 oncall orders at tick 944.
# Processing 1 oncall orders at tick 946.
# Processing 1 oncall orders at tick 961.
# Processing 1 oncall orders at tick 983.
# Processing 1 oncall orders at tick 1169.
# carrier_idx: 35, route_name: 528, remaining plan: 1 [Order]: id: dummy_rtb_order, coord: (32.72329, -117.07189), status: OrderStatus.DUMMY, open time: 0, close time: 1420
# 1419
# {'total_oncall_num': 338, 'unallocated_oncall_num': 0, 'total_order_num': 8160, 'total_order_in_advance': 15, 'total_order_delayed': 10, 'total_order_delay_time': 173, 'total_order_terminated': 224, 'total_order_completed': 7936, 'pending_order_num': 0, 'route_finish_tick': {'136': 37, '137': 52, '156': 47, '157': 44, '165': 58, '166': 51, '175': 46, '177': 38, '315': 93, '316': 98, '317': 321, '318': 279, '319': 310, '327': 147, '328': 231, '329': 238, '337': 178, '338': 222, '339': 216, '347': 62, '348': 131, '349': 212, '357': 64, '358': 167, '359': 135, '368': 141, '369': 172, '39': 195, '390': 76, '517': 313, '518': 188, '519': 229, '525': 178, '526': 196, '527': 307, '528': -1, '529': 340, '538': 222, '539': 270, '546': 195, '547': 242, '548': 375, '549': 307, '557': 131, '558': 315, '559': 338, '562': 179, '563': 286, '566': 253, '567': 221, '575': 180, '576': 281, '577': 292, '578': 352, '579': 334, '626': 110, '627': 233, '628': 262, '629': 245, '637': 213, '638': 352, '639': 211, '645': 274, '646': 275, '647': 289, '648': 277, '649': 345, '657': 83, '658': 245, '659': 229, '664': 137, '665': 412, '667': 389, '668': 313, '669': 320, '677': 326, '678': 368, '679': 308, '689': 224, '69': 143, '801': 53, '803': 33, '805': 75, '815': 54, '816': 74, '828': 58, '835': 67, '838': 68, '839': 50, '857': 65, '868': 53, '914': 262, '915': 300, '916': 322, '917': 338, '918': 349, '919': 325, '925': 204, '926': 347, '927': 364, '928': 296, '929': 330, '936': 239, '937': 361, '938': 284, '939': 221, '957': 114, '958': 205, '959': 258, '967': 270, '968': 279, '969': 336, '978': 228, '979': 303, '985': 40, '987': 218, '99': 203}, 'route_order_cnt': {'39': 59, '69': 37, '99': 65, '136': 3, '137': 5, '156': 5, '157': 4, '165': 4, '166': 4, '175': 6, '177': 5, '315': 24, '316': 28, '317': 103, '318': 98, '319': 94, '327': 52, '328': 76, '329': 76, '337': 56, '338': 80, '339': 76, '347': 28, '348': 70, '349': 60, '357': 14, '358': 77, '359': 61, '368': 88, '369': 91, '390': 20, '517': 92, '518': 75, '519': 79, '525': 54, '526': 68, '527': 93, '528': 450, '529': 87, '538': 72, '539': 87, '546': 52, '547': 77, '548': 115, '549': 76, '557': 37, '558': 103, '559': 85, '562': 24, '563': 50, '566': 62, '567': 30, '575': 56, '576': 90, '577': 95, '578': 111, '579': 110, '626': 37, '627': 87, '628': 101, '629': 81, '637': 61, '638': 115, '639': 75, '645': 69, '646': 92, '647': 85, '648': 90, '649': 93, '657': 22, '658': 83, '659': 67, '664': 35, '665': 95, '667': 129, '668': 109, '669': 116, '677': 105, '678': 111, '679': 97, '689': 44, '801': 17, '803': 4, '805': 14, '815': 13, '816': 16, '828': 12, '835': 17, '838': 17, '839': 13, '857': 12, '868': 9, '914': 70, '915': 95, '916': 107, '917': 123, '918': 124, '919': 113, '925': 66, '926': 113, '927': 108, '928': 100, '929': 121, '936': 78, '937': 119, '938': 101, '939': 74, '957': 31, '958': 85, '959': 94, '967': 75, '968': 90, '969': 105, '978': 76, '979': 90, '985': 10, '987': 50}, 'min_max_avg_order_cnt': [3, 450, 69.74358974358974]}

# %%
df_cnt = df[((df['tick']==1419) & (df['type'] == "ONCALL"))].groupby('route_name').count().reset_index()
df_cnt.sort_values(by='order_id', inplace=True, ascending=False)
df_cnt.head()
# Out:
#   route_name  tick  type  order_lat  order_lng  finish_tick  open_time  \
# 0        528   335   335        335        335          335        335
# 1        649     1     1          1          1            1          1
# 2        665     1     1          1          1            1          1
# 3        927     1     1          1          1            1          1
#
#    close_time  is_delivery  order_status  carrier_id  carrier_lat  \
# 0         335          335           335         335          335
# 1           1            1             1           1            1
# 2           1            1             1           1            1
# 3           1            1             1           1            1
#
#    carrier_lng  order_id
# 0          335       335
# 1            1         1
# 2            1         1
# 3            1         1

# %%
df[((df['tick']==1419) & (df['route_name'] == "528") & (df['type'] == "ONCALL"))]
# Out:
#       tick route_name    type  order_lat  order_lng  finish_tick  open_time  \
# 1963  1419        528  ONCALL   32.78989 -117.25326          460        480
# 1964  1419        528  ONCALL   32.65090 -116.96133          471        480
# 1965  1419        528  ONCALL   32.62957 -116.96505          540        570
# 1966  1419        528  ONCALL   32.65221 -116.96316          630        660
# 1967  1419        528  ONCALL   32.62127 -116.96610          639        588
# ...    ...        ...     ...        ...        ...          ...        ...
# 2306  1419        528  ONCALL   32.74262 -116.97233         1412        810
# 2309  1419        528  ONCALL   32.73401 -117.05698         1417        840
# 2310  1419        528  ONCALL   32.73255 -117.05835         1417        660
# 2311  1419        528  ONCALL   32.72220 -117.07204         1417        600
# 2312  1419        528  ONCALL   32.73538 -117.07723         1417        574
#
#       close_time is_delivery order_status  carrier_id  carrier_lat  \
# 1963         600       False     Complete          35         -1.0
# 1964         810       False     Complete          35         -1.0
# 1965         720       False     Complete          35         -1.0
# 1966         900       False     Complete          35         -1.0
# 1967         708       False     Complete          35         -1.0
# ...          ...         ...          ...         ...          ...
# 2306        1260       False   Terminated          35         -1.0
# 2309        1380       False   Terminated          35         -1.0
# 2310         840       False   Terminated          35         -1.0
# 2311         721       False   Terminated          35         -1.0
# 2312         724       False   Terminated          35         -1.0
#
#       carrier_lng     order_id
# 1963         -1.0  oncall_0156
# 1964         -1.0  oncall_0062
# 1965         -1.0  oncall_0097
# 1966         -1.0  oncall_0277
# 1967         -1.0  oncall_0090
# ...           ...          ...
# 2306         -1.0  oncall_0084
# 2309         -1.0  oncall_0069
# 2310         -1.0  oncall_0229
# 2311         -1.0  oncall_0094
# 2312         -1.0  oncall_0272
#
# [335 rows x 14 columns]
